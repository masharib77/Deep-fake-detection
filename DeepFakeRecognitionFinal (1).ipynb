# %% [markdown]
# **Deep Fake Recognition using Deep Learning Techniques**

# %%
# mounting google drive
import pandas as pd
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.environ['KAGGLE_CONFIG_DIR'] ='/content/drive/MyDrive/Kaggle'

# %%
# %cd /content/drive/MyDrive/Kaggle
# Out:
# /content/drive/MyDrive/Kaggle

# %% [markdown]
# View a sample image

# %%
import cv2
from google.colab.patches import cv2_imshow
from PIL import Image
import matplotlib.pyplot as plt
img = Image.open('/content/drive/MyDrive/Kaggle/real_and_fake_face_detection/Train/fake/0BKA6H4EE4.jpg').convert('RGB')
plt.imshow(img)

# %% [markdown]
# **Vision Transformer Based Model**

# %%
import cv2
import math
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import utils
from sklearn.metrics import confusion_matrix
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Dropout
from keras.models import Sequential, load_model
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
# !pip install -U tensorflow-addons
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image, ImageChops, ImageEnhance
import os
import itertools
import random
# %matplotlib inline
import cv2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.19.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow-addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.8/dist-packages (from tensorflow-addons) (2.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->tensorflow-addons) (3.0.9)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.19.0

# %%
image_size = 224
labels = ('real', 'fake')
def get_data(data_dir):
    data = []
    for label in labels:
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[..., ::-1]
                resized_arr = cv2.resize(img_arr, (image_size, image_size))
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)

    return np.array(data, dtype='object')

# %%
train = get_data("/content/drive/MyDrive/Kaggle/real_and_fake_face_detection/Train/")
test = get_data("/content/drive/MyDrive/Kaggle/real_and_fake_face_detection/Test/")
print(train.shape)
print(test.shape)
# Out:
# (1920, 2)
# (2041, 2)

# %%
l = []
for i in train:
    if i[1] == 0:
        l.append('real')
    else:
        l.append('fake')

# %%
plt.figure(figsize=(8, 4))
plt.title('Count of Real vs Fake Images  ', size=16)
sns.countplot(x=l)
plt.show()

# randomly visualizing images
plt.figure(figsize=(8, 6))
plt.imshow(train[1][0])
plt.title(labels[train[0][1]])
plt.show()

plt.figure(figsize=(10, 6))
plt.imshow(train[-1][0])
plt.title(labels[train[-1][1]])
plt.show()

X_train = []
X_test = []
y_train = []
y_test = []

# dividing data into train and test sets
for feature, label in train:
    X_train.append(feature)
    y_train.append(label)

for feature, label in test:
    X_test.append(feature)
    y_test.append(label)

# Normalise the image data
X_train = np.array(X_train)

X_test = np.array(X_test)

# # Reshaping the image data so that every image is the same size
y_train = np.array(y_train)
y_test = np.array(y_test)


y_test = np.array(y_test)
print (X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1920, 224, 224, 3)
# (2041, 224, 224, 3)
# (1920,)
# (2041,)

# %%
# !pip install -U tensorflow-addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.8/dist-packages (0.19.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.8/dist-packages (from tensorflow-addons) (2.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow-addons) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->tensorflow-addons) (3.0.9)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa

# %%
num_classes = 2
input_shape = (224, 224, 3)

# %% [markdown]
# Vision Transformer parameters

# %%
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 256
num_epochs = 80
image_size = 72
patch_size = 6
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [projection_dim * 2 , projection_dim,]
  
# Size of the transformer layers
transformer_layers = 8
mlp_head_units = [2048, 1024]  # Size of the dense layers of the final classifier

# %% [markdown]
# Data Augmentation to calculate mean and variance

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)

data_augmentation.layers[0].adapt(X_train)

# %% [markdown]
# MLP

# %%
# multilayer perceptron
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %% [markdown]
# Class to generate Patches

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %% [markdown]
# Patch Visualisation

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(4, 4))
image = X_train[np.random.choice(range(X_train.shape[0]))]
plt.imshow(image.astype("uint8"))
plt.axis("off")

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("uint8"))
    plt.axis("off")
# Out:
# Image size: 72 X 72
# Patch size: 6 X 6
# Patches per image: 144
# Elements per patch: 108

# %% [markdown]
# Patch Encoder class

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %% [markdown]
# Creating VIT Model

# %%
def create_vit_classifier():
    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)

        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add multilayer perceptron.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)

    return model

# %% [markdown]
# Vision Transformer (VIT) Model

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix

from sklearn.metrics import ConfusionMatrixDisplay

def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )
    history = model.fit(
        x=X_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
    )
    predictions = np.argmax(model.predict(X_test), axis=-1)

# Regain the original shape to evaluate predictions
    predictions = predictions.reshape(1, -1)[0]

    # Print classification report
    print(classification_report(y_test, predictions, target_names=['Healthy(class 0)', 'UnHealthy(class 1)']))
    print("Accuracy: ", metrics.accuracy_score(y_test, predictions) * 100)
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(50)

    plt.figure(figsize=(15, 15))
    plt.subplot(2, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

    #building the confusion matrix
    result = confusion_matrix(y_test, predictions , normalize='pred')
    print(result)
    labels = ["Fake", "Real"]
    cm = confusion_matrix(y_test, predictions)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)

    disp.plot(cmap=plt.cm.Blues)
    plt.show()
    return history


vit_classifier = create_vit_classifier()
history = run_experiment(vit_classifier)
# Out:
# Epoch 1/80
# 7/7 [==============================] - 128s 14s/step - loss: 3.5878 - accuracy: 0.5295 - top-5-accuracy: 1.0000 - val_loss: 0.3968 - val_accuracy: 0.8073 - val_top-5-accuracy: 1.0000
# Epoch 2/80
# 7/7 [==============================] - 99s 14s/step - loss: 1.0098 - accuracy: 0.6285 - top-5-accuracy: 1.0000 - val_loss: 0.8032 - val_accuracy: 0.5000 - val_top-5-accuracy: 1.0000
# Epoch 3/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.8645 - accuracy: 0.6279 - top-5-accuracy: 1.0000 - val_loss: 0.5844 - val_accuracy: 0.6042 - val_top-5-accuracy: 1.0000
# Epoch 4/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.6934 - accuracy: 0.6562 - top-5-accuracy: 1.0000 - val_loss: 0.5354 - val_accuracy: 0.6562 - val_top-5-accuracy: 1.0000
# Epoch 5/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.6259 - accuracy: 0.6997 - top-5-accuracy: 1.0000 - val_loss: 0.5870 - val_accuracy: 0.6354 - val_top-5-accuracy: 1.0000
# Epoch 6/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.5631 - accuracy: 0.7164 - top-5-accuracy: 1.0000 - val_loss: 0.7557 - val_accuracy: 0.4479 - val_top-5-accuracy: 1.0000
# Epoch 7/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.5766 - accuracy: 0.7303 - top-5-accuracy: 1.0000 - val_loss: 0.6089 - val_accuracy: 0.6250 - val_top-5-accuracy: 1.0000
# Epoch 8/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.5627 - accuracy: 0.7355 - top-5-accuracy: 1.0000 - val_loss: 0.6912 - val_accuracy: 0.5521 - val_top-5-accuracy: 1.0000
# Epoch 9/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.5447 - accuracy: 0.7361 - top-5-accuracy: 1.0000 - val_loss: 0.6841 - val_accuracy: 0.5573 - val_top-5-accuracy: 1.0000
# Epoch 10/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.5060 - accuracy: 0.7477 - top-5-accuracy: 1.0000 - val_loss: 0.5599 - val_accuracy: 0.6667 - val_top-5-accuracy: 1.0000
# Epoch 11/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.5028 - accuracy: 0.7569 - top-5-accuracy: 1.0000 - val_loss: 0.5938 - val_accuracy: 0.6250 - val_top-5-accuracy: 1.0000
# Epoch 12/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.4974 - accuracy: 0.7645 - top-5-accuracy: 1.0000 - val_loss: 0.7807 - val_accuracy: 0.4896 - val_top-5-accuracy: 1.0000
# Epoch 13/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.4925 - accuracy: 0.7529 - top-5-accuracy: 1.0000 - val_loss: 0.6369 - val_accuracy: 0.6458 - val_top-5-accuracy: 1.0000
# Epoch 14/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.4699 - accuracy: 0.7749 - top-5-accuracy: 1.0000 - val_loss: 0.6318 - val_accuracy: 0.5729 - val_top-5-accuracy: 1.0000
# Epoch 15/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.4629 - accuracy: 0.7784 - top-5-accuracy: 1.0000 - val_loss: 0.4910 - val_accuracy: 0.7396 - val_top-5-accuracy: 1.0000
# Epoch 16/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.4539 - accuracy: 0.7882 - top-5-accuracy: 1.0000 - val_loss: 0.5182 - val_accuracy: 0.7344 - val_top-5-accuracy: 1.0000
# Epoch 17/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.4218 - accuracy: 0.8021 - top-5-accuracy: 1.0000 - val_loss: 0.4164 - val_accuracy: 0.8438 - val_top-5-accuracy: 1.0000
# Epoch 18/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.4334 - accuracy: 0.8038 - top-5-accuracy: 1.0000 - val_loss: 0.3844 - val_accuracy: 0.8646 - val_top-5-accuracy: 1.0000
# Epoch 19/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.3982 - accuracy: 0.8206 - top-5-accuracy: 1.0000 - val_loss: 0.3968 - val_accuracy: 0.8542 - val_top-5-accuracy: 1.0000
# Epoch 20/80
# 7/7 [==============================] - 96s 14s/step - loss: 0.3821 - accuracy: 0.8333 - top-5-accuracy: 1.0000 - val_loss: 0.3804 - val_accuracy: 0.8594 - val_top-5-accuracy: 1.0000
# Epoch 21/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.3984 - accuracy: 0.8148 - top-5-accuracy: 1.0000 - val_loss: 0.4536 - val_accuracy: 0.8073 - val_top-5-accuracy: 1.0000
# Epoch 22/80
# 7/7 [==============================] - 99s 14s/step - loss: 0.3868 - accuracy: 0.8206 - top-5-accuracy: 1.0000 - val_loss: 0.5221 - val_accuracy: 0.7135 - val_top-5-accuracy: 1.0000
# Epoch 23/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.3882 - accuracy: 0.8252 - top-5-accuracy: 1.0000 - val_loss: 0.5246 - val_accuracy: 0.7396 - val_top-5-accuracy: 1.0000
# Epoch 24/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.3791 - accuracy: 0.8293 - top-5-accuracy: 1.0000 - val_loss: 0.4753 - val_accuracy: 0.8229 - val_top-5-accuracy: 1.0000
# Epoch 25/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.3597 - accuracy: 0.8397 - top-5-accuracy: 1.0000 - val_loss: 0.4252 - val_accuracy: 0.8490 - val_top-5-accuracy: 1.0000
# Epoch 26/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.3407 - accuracy: 0.8420 - top-5-accuracy: 1.0000 - val_loss: 0.4384 - val_accuracy: 0.8646 - val_top-5-accuracy: 1.0000
# Epoch 27/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.3513 - accuracy: 0.8449 - top-5-accuracy: 1.0000 - val_loss: 0.5099 - val_accuracy: 0.7917 - val_top-5-accuracy: 1.0000
# Epoch 28/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.3504 - accuracy: 0.8339 - top-5-accuracy: 1.0000 - val_loss: 0.4234 - val_accuracy: 0.8385 - val_top-5-accuracy: 1.0000
# Epoch 29/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.3237 - accuracy: 0.8519 - top-5-accuracy: 1.0000 - val_loss: 0.3213 - val_accuracy: 0.9219 - val_top-5-accuracy: 1.0000
# Epoch 30/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.3274 - accuracy: 0.8536 - top-5-accuracy: 1.0000 - val_loss: 0.3186 - val_accuracy: 0.9375 - val_top-5-accuracy: 1.0000
# Epoch 31/80
# 7/7 [==============================] - 98s 14s/step - loss: 0.3079 - accuracy: 0.8663 - top-5-accuracy: 1.0000 - val_loss: 0.4860 - val_accuracy: 0.7708 - val_top-5-accuracy: 1.0000
# Epoch 32/80
# 7/7 [==============================] - 99s 14s/step - loss: 0.3292 - accuracy: 0.8675 - top-5-accuracy: 1.0000 - val_loss: 0.3426 - val_accuracy: 0.8646 - val_top-5-accuracy: 1.0000
# Epoch 33/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.3178 - accuracy: 0.8704 - top-5-accuracy: 1.0000 - val_loss: 0.2788 - val_accuracy: 0.9323 - val_top-5-accuracy: 1.0000
# Epoch 34/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.3413 - accuracy: 0.8553 - top-5-accuracy: 1.0000 - val_loss: 0.4311 - val_accuracy: 0.8229 - val_top-5-accuracy: 1.0000
# Epoch 35/80
# 7/7 [==============================] - 96s 14s/step - loss: 0.3217 - accuracy: 0.8686 - top-5-accuracy: 1.0000 - val_loss: 0.4890 - val_accuracy: 0.7865 - val_top-5-accuracy: 1.0000
# Epoch 36/80
# 7/7 [==============================] - 96s 14s/step - loss: 0.2978 - accuracy: 0.8669 - top-5-accuracy: 1.0000 - val_loss: 0.4441 - val_accuracy: 0.8438 - val_top-5-accuracy: 1.0000
# Epoch 37/80
# 7/7 [==============================] - 96s 14s/step - loss: 0.2948 - accuracy: 0.8640 - top-5-accuracy: 1.0000 - val_loss: 0.2906 - val_accuracy: 0.9271 - val_top-5-accuracy: 1.0000
# Epoch 38/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.2818 - accuracy: 0.8744 - top-5-accuracy: 1.0000 - val_loss: 0.3602 - val_accuracy: 0.8854 - val_top-5-accuracy: 1.0000
# Epoch 39/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.2837 - accuracy: 0.8779 - top-5-accuracy: 1.0000 - val_loss: 0.3664 - val_accuracy: 0.8750 - val_top-5-accuracy: 1.0000
# Epoch 40/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.2738 - accuracy: 0.8866 - top-5-accuracy: 1.0000 - val_loss: 0.4048 - val_accuracy: 0.8281 - val_top-5-accuracy: 1.0000
# Epoch 41/80
# 7/7 [==============================] - 96s 14s/step - loss: 0.2838 - accuracy: 0.8791 - top-5-accuracy: 1.0000 - val_loss: 0.2863 - val_accuracy: 0.9115 - val_top-5-accuracy: 1.0000
# Epoch 42/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.2812 - accuracy: 0.8848 - top-5-accuracy: 1.0000 - val_loss: 0.3424 - val_accuracy: 0.8594 - val_top-5-accuracy: 1.0000
# Epoch 43/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.2790 - accuracy: 0.8981 - top-5-accuracy: 1.0000 - val_loss: 0.2596 - val_accuracy: 0.9375 - val_top-5-accuracy: 1.0000
# Epoch 44/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.2852 - accuracy: 0.8767 - top-5-accuracy: 1.0000 - val_loss: 0.3220 - val_accuracy: 0.8802 - val_top-5-accuracy: 1.0000
# Epoch 45/80
# 7/7 [==============================] - 96s 14s/step - loss: 0.2503 - accuracy: 0.8918 - top-5-accuracy: 1.0000 - val_loss: 0.3342 - val_accuracy: 0.8750 - val_top-5-accuracy: 1.0000
# Epoch 46/80
# 7/7 [==============================] - 96s 14s/step - loss: 0.2472 - accuracy: 0.8999 - top-5-accuracy: 1.0000 - val_loss: 0.7291 - val_accuracy: 0.7240 - val_top-5-accuracy: 1.0000
# Epoch 47/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.2404 - accuracy: 0.9068 - top-5-accuracy: 1.0000 - val_loss: 0.3281 - val_accuracy: 0.9115 - val_top-5-accuracy: 1.0000
# Epoch 48/80
# 7/7 [==============================] - 101s 15s/step - loss: 0.2406 - accuracy: 0.8976 - top-5-accuracy: 1.0000 - val_loss: 0.3195 - val_accuracy: 0.8854 - val_top-5-accuracy: 1.0000
# Epoch 49/80
# 7/7 [==============================] - 101s 14s/step - loss: 0.2426 - accuracy: 0.8999 - top-5-accuracy: 1.0000 - val_loss: 0.3342 - val_accuracy: 0.8698 - val_top-5-accuracy: 1.0000
# Epoch 50/80
# 7/7 [==============================] - 98s 14s/step - loss: 0.2346 - accuracy: 0.8981 - top-5-accuracy: 1.0000 - val_loss: 0.4014 - val_accuracy: 0.8646 - val_top-5-accuracy: 1.0000
# Epoch 51/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.2317 - accuracy: 0.9068 - top-5-accuracy: 1.0000 - val_loss: 0.4019 - val_accuracy: 0.8594 - val_top-5-accuracy: 1.0000
# Epoch 52/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.2114 - accuracy: 0.9103 - top-5-accuracy: 1.0000 - val_loss: 0.2741 - val_accuracy: 0.9115 - val_top-5-accuracy: 1.0000
# Epoch 53/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.2072 - accuracy: 0.9213 - top-5-accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9323 - val_top-5-accuracy: 1.0000
# Epoch 54/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.2298 - accuracy: 0.9057 - top-5-accuracy: 1.0000 - val_loss: 0.4598 - val_accuracy: 0.8177 - val_top-5-accuracy: 1.0000
# Epoch 55/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.2028 - accuracy: 0.9230 - top-5-accuracy: 1.0000 - val_loss: 0.3026 - val_accuracy: 0.9115 - val_top-5-accuracy: 1.0000
# Epoch 56/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.2069 - accuracy: 0.9120 - top-5-accuracy: 1.0000 - val_loss: 0.3828 - val_accuracy: 0.8490 - val_top-5-accuracy: 1.0000
# Epoch 57/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.1992 - accuracy: 0.9161 - top-5-accuracy: 1.0000 - val_loss: 0.1933 - val_accuracy: 0.9427 - val_top-5-accuracy: 1.0000
# Epoch 58/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.2431 - accuracy: 0.8941 - top-5-accuracy: 1.0000 - val_loss: 0.3013 - val_accuracy: 0.8854 - val_top-5-accuracy: 1.0000
# Epoch 59/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.2101 - accuracy: 0.9109 - top-5-accuracy: 1.0000 - val_loss: 0.3552 - val_accuracy: 0.8854 - val_top-5-accuracy: 1.0000
# Epoch 60/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.1916 - accuracy: 0.9225 - top-5-accuracy: 1.0000 - val_loss: 0.3770 - val_accuracy: 0.8438 - val_top-5-accuracy: 1.0000
# Epoch 61/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.1803 - accuracy: 0.9184 - top-5-accuracy: 1.0000 - val_loss: 0.4366 - val_accuracy: 0.8229 - val_top-5-accuracy: 1.0000
# Epoch 62/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.1801 - accuracy: 0.9253 - top-5-accuracy: 1.0000 - val_loss: 0.4453 - val_accuracy: 0.8490 - val_top-5-accuracy: 1.0000
# Epoch 63/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.1793 - accuracy: 0.9288 - top-5-accuracy: 1.0000 - val_loss: 0.5677 - val_accuracy: 0.8021 - val_top-5-accuracy: 1.0000
# Epoch 64/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.2058 - accuracy: 0.9167 - top-5-accuracy: 1.0000 - val_loss: 0.2675 - val_accuracy: 0.9010 - val_top-5-accuracy: 1.0000
# Epoch 65/80
# 7/7 [==============================] - 96s 14s/step - loss: 0.1654 - accuracy: 0.9352 - top-5-accuracy: 1.0000 - val_loss: 0.2772 - val_accuracy: 0.8958 - val_top-5-accuracy: 1.0000
# Epoch 66/80
# 7/7 [==============================] - 96s 14s/step - loss: 0.1547 - accuracy: 0.9363 - top-5-accuracy: 1.0000 - val_loss: 0.4355 - val_accuracy: 0.8542 - val_top-5-accuracy: 1.0000
# Epoch 67/80
# 7/7 [==============================] - 96s 14s/step - loss: 0.1547 - accuracy: 0.9311 - top-5-accuracy: 1.0000 - val_loss: 0.2251 - val_accuracy: 0.9219 - val_top-5-accuracy: 1.0000
# Epoch 68/80
# 7/7 [==============================] - 96s 14s/step - loss: 0.1496 - accuracy: 0.9421 - top-5-accuracy: 1.0000 - val_loss: 0.3212 - val_accuracy: 0.8854 - val_top-5-accuracy: 1.0000
# Epoch 69/80
# 7/7 [==============================] - 96s 14s/step - loss: 0.1698 - accuracy: 0.9334 - top-5-accuracy: 1.0000 - val_loss: 0.2422 - val_accuracy: 0.9219 - val_top-5-accuracy: 1.0000
# Epoch 70/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.1500 - accuracy: 0.9381 - top-5-accuracy: 1.0000 - val_loss: 0.2956 - val_accuracy: 0.8906 - val_top-5-accuracy: 1.0000
# Epoch 71/80
# 7/7 [==============================] - 96s 14s/step - loss: 0.2035 - accuracy: 0.9265 - top-5-accuracy: 1.0000 - val_loss: 0.4553 - val_accuracy: 0.8385 - val_top-5-accuracy: 1.0000
# Epoch 72/80
# 7/7 [==============================] - 97s 14s/step - loss: 0.1724 - accuracy: 0.9265 - top-5-accuracy: 1.0000 - val_loss: 0.3820 - val_accuracy: 0.8385 - val_top-5-accuracy: 1.0000
# Epoch 73/80
# 7/7 [==============================] - 96s 14s/step - loss: 0.1623 - accuracy: 0.9410 - top-5-accuracy: 1.0000 - val_loss: 0.3598 - val_accuracy: 0.8594 - val_top-5-accuracy: 1.0000
# Epoch 74/80
# 7/7 [==============================] - 96s 14s/step - loss: 0.1559 - accuracy: 0.9381 - top-5-accuracy: 1.0000 - val_loss: 0.2753 - val_accuracy: 0.9010 - val_top-5-accuracy: 1.0000
# Epoch 75/80
# 7/7 [==============================] - 96s 14s/step - loss: 0.1391 - accuracy: 0.9485 - top-5-accuracy: 1.0000 - val_loss: 0.5188 - val_accuracy: 0.7917 - val_top-5-accuracy: 1.0000
# Epoch 76/80
# 7/7 [==============================] - 96s 14s/step - loss: 0.1381 - accuracy: 0.9514 - top-5-accuracy: 1.0000 - val_loss: 0.4174 - val_accuracy: 0.8385 - val_top-5-accuracy: 1.0000
# Epoch 77/80
# 7/7 [==============================] - 96s 14s/step - loss: 0.1274 - accuracy: 0.9485 - top-5-accuracy: 1.0000 - val_loss: 0.3844 - val_accuracy: 0.8906 - val_top-5-accuracy: 1.0000
# Epoch 78/80
# 7/7 [==============================] - 96s 14s/step - loss: 0.1489 - accuracy: 0.9398 - top-5-accuracy: 1.0000 - val_loss: 0.4431 - val_accuracy: 0.8385 - val_top-5-accuracy: 1.0000
# Epoch 79/80
# 7/7 [==============================] - 96s 14s/step - loss: 0.1435 - accuracy: 0.9456 - top-5-accuracy: 1.0000 - val_loss: 0.4914 - val_accuracy: 0.8229 - val_top-5-accuracy: 1.0000
# Epoch 80/80
# 7/7 [==============================] - 96s 14s/step - loss: 0.1383 - accuracy: 0.9468 - top-5-accuracy: 1.0000 - val_loss: 0.5071 - val_accuracy: 0.8125 - val_top-5-accuracy: 1.0000
# 64/64 [==============================] - 39s 586ms/step
#                     precision    recall  f1-score   support
#
#   Healthy(class 0)       0.53      0.87      0.66      1081
# UnHealthy(class 1)       0.48      0.13      0.21       960
#
#           accuracy                           0.52      2041
#          macro avg       0.50      0.50      0.43      2041
#       weighted avg       0.51      0.52      0.45      2041
#
# Accuracy:  52.37628613424792
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-8572dd8d4a28> in <module>
#      82
#      83 vit_classifier = create_vit_classifier()
# ---> 84 history = run_experiment(vit_classifier)
#
# <ipython-input-20-8572dd8d4a28> in run_experiment(model)
#      52     plt.figure(figsize=(15, 15))
#      53     plt.subplot(2, 2, 1)
# ---> 54     plt.plot(epochs_range, acc, label='Training Accuracy')
#      55     plt.plot(epochs_range, val_acc, label='Validation Accuracy')
#      56     plt.legend(loc='lower right')
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2759 @docstring.copy(Axes.plot)
#    2760 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2763         is not None else {}), **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     340
#     341         if x.shape[0] != y.shape[0]:
# --> 342             raise ValueError(f"x and y must have same first dimension, but "
#     343                              f"have shapes {x.shape} and {y.shape}")
#     344         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (50,) and (80,)

# %% [markdown]
# **Efficient Net Implementation CNN**

# %%
base_model = tf.keras.applications.efficientnet.EfficientNetB7(input_shape=(224, 224, 3), include_top=False, weights='imagenet')

base_model.trainable = False

# keras tuner to find the best architecture
model = tf.keras.Sequential([base_model, tf.keras.layers.GlobalAveragePooling2D(),
                             tf.keras.layers.Dropout(0.2),
                             tf.keras.layers.Dense(2, activation='softmax')])

model.compile(optimizer=keras.optimizers.Adam(0.001), loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# callback for early stopping
# patience is the number of epochs wth no improvement after which the training will be stopped
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))

from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

predictions = np.argmax(model.predict(X_test), axis=-1)
predictions = predictions.reshape(1, -1)[0]

# print the classification report
print(classification_report(y_test, predictions, target_names=['real(class 0)', 'fake(class 1)']))
print("Accuracy: ", metrics.accuracy_score(y_test, predictions) * 100)
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(50)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy') 

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **Save Model**

# %%
model.save("deepfakefinal.h5")
